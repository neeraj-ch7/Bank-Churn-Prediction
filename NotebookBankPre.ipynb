# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
bank = pd.read_csv(r"C:\Users\ASUS\Downloads\Bank Customer Churn Prediction.csv")

# %%
bank = bank.head(100)

# %%
bank
# Out:
#     customer_id  credit_score  country  gender  age  tenure    balance  \
# 0      15634602           619   France  Female   42       2       0.00
# 1      15647311           608    Spain  Female   41       1   83807.86
# 2      15619304           502   France  Female   42       8  159660.80
# 3      15701354           699   France  Female   39       1       0.00
# 4      15737888           850    Spain  Female   43       2  125510.82
# ..          ...           ...      ...     ...  ...     ...        ...
# 95     15699461           515    Spain    Male   35      10  176273.95
# 96     15738721           773    Spain    Male   41       9  102827.44
# 97     15693683           814  Germany    Male   29       8   97086.40
# 98     15604348           710    Spain    Male   22       8       0.00
# 99     15633059           413   France    Male   34       9       0.00
#
#     products_number  credit_card  active_member  estimated_salary  churn
# ...

# %%
sns.scatterplot(x = bank['credit_score'],y = bank['age'],c = bank['churn'])
# Out:
# <Axes: xlabel='credit_score', ylabel='age'>

# %%
bank.drop(["customer_id","country","gender","tenure","balance","products_number","credit_card","active_member","estimated_salary"], axis=1, inplace=True)

# %%
bank
# Out:
#     credit_score  age  churn
# 0            619   42      1
# 1            608   41      0
# 2            502   42      1
# 3            699   39      0
# 4            850   43      0
# ..           ...  ...    ...
# 95           515   35      0
# 96           773   41      0
# 97           814   29      0
# 98           710   22      0
# 99           413   34      0
#
# [100 rows x 3 columns]

# %%
X =bank.iloc[:,0:2]
y = bank.iloc[:,-1]

# %%
X
# Out:
#     credit_score  age
# 0            619   42
# 1            608   41
# 2            502   42
# 3            699   39
# 4            850   43
# ..           ...  ...
# 95           515   35
# 96           773   41
# 97           814   29
# 98           710   22
# 99           413   34
#
# [100 rows x 2 columns]

# %%
y
# Out:
# 0     1
# 1     0
# 2     1
# 3     0
# 4     0
#      ..
# 95    0
# 96    0
# 97    0
# 98    0
# 99    0
# Name: churn, Length: 100, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train,X_test,y_train,y_test=train_test_split(X,y,test_size=0.1)

# %%
X_train
# Out:
#     credit_score  age
# 66           581   34
# 80           665   34
# 90           647   44
# 52           788   33
# 60           742   35
# ..           ...  ...
# 7            376   29
# 21           636   32
# 82           543   36
# 31           533   36
# 47           637   39
#
# [90 rows x 2 columns]

# %%
y_train
# Out:
# 66    0
# 80    0
# 90    1
# 52    0
# 60    0
#      ..
# 7     1
# 21    0
# 82    0
# 31    0
# 47    1
# Name: churn, Length: 90, dtype: int64

# %%
from sklearn.preprocessing import StandardScaler

# %%
scaler =  StandardScaler()

# %%
X_train=scaler.fit_transform(X_train)

# %%
X_train
# Out:
# array([[-0.49625557, -0.35170385],
#        [ 0.22177163, -0.35170385],
#        [ 0.06790866,  0.62525129],
#        [ 1.27316858, -0.44939936],
#        [ 0.87996322, -0.25400833],
#        [-1.01768007,  0.42986026],
#        [ 0.50385374,  0.62525129],
#        [ 0.99963442, -0.15631282],
#        [ 0.73464819, -1.81713655],
#        [-0.70995413,  2.28607501],
#        [ 1.40993567, -0.44939936],
#        [ 0.14484014,  0.7229468 ],
#        [ 0.15338808, -0.05861731],
#        [ 0.40982637, -1.03557244],
#        [ 0.79448379,  0.33216475],
#        [ 1.80314103,  0.52755577],
#        [ 0.05081277,  0.62525129],
#        [ 0.82012762,  0.52755577],
#        [-1.42798133,  0.23446923],
#        [ 0.9568947 , -0.15631282],
#        [ 1.00818236, -0.44939936],
#        [-0.53044734, -1.23096347],
#        [-1.24847453,  0.82064231],
#        [-1.48781692,  1.30911988],
#        [-0.03466666, -0.93787693],
#        [-1.17154304,  0.42986026],
#        [-0.73559796,  0.33216475],
# ...

# %%
X_test=scaler.fit_transform(X_test)

# %%
X_test
# Out:
# array([[ 0.42235623,  0.52941176],
#        [ 0.62033571,  1.70588235],
#        [-1.14828099, -0.41176471],
#        [-0.30356854,  1.11764706],
#        [-0.38276033, -0.05882353],
#        [-0.72592476, -0.05882353],
#        [ 1.17467825, -2.05882353],
#        [-1.61023311, -0.76470588],
#        [ 0.11878769,  0.52941176],
#        [ 1.83460986, -0.52941176]])

# %%
from sklearn.linear_model import LogisticRegression

# %%
clf=LogisticRegression()

# %%
clf.fit(X_train,y_train)
# Out:
# LogisticRegression()

# %%
y_pred=clf.predict(X_test)

# %%
y_test
# Out:
# 23    0
# 63    0
# 48    0
# 59    0
# 1     0
# 39    0
# 19    0
# 95    0
# 88    1
# 49    0
# Name: churn, dtype: int64

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test,y_pred)
# Out:
# 0.9

# %%
from mlxtend.plotting import plot_decision_regions
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[73], line 1
# ----> 1 from mlxtend.plotting import plot_decision_regions
#
# ModuleNotFoundError: No module named 'mlxtend'

# %% [markdown]
# # Assistant
# This error occurs because the Python module 'mlxtend' is not installed in your environment. The error message "No module named 'mlxtend'" indicates that Python cannot find this package when you try to import it.
#
# Would you like me to provide the corrected code?

# %%
# First, install the mlxtend package
# !pip install mlxtend

# Then import the module
from mlxtend.plotting import plot_decision_regions

# Note: You may need to restart your kernel after installing the package
# for the changes to take effect
# Out:
# ...
#   Using cached mlxtend-0.24.0-py3-none-any.whl.metadata (7.3 kB)
# ...
# Using cached mlxtend-0.24.0-py3-none-any.whl (1.4 MB)
# ...
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\ASUS\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\ASUS\anaconda3\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~atplotlib (C:\Users\ASUS\anaconda3\Lib\site-packages)

# %%
plot_decision_regions(X_train, y_train.values, clf=clf, legend=2)
# Out:
# <Axes: >

# %%
import pickle

# %%
pickle.dump(clf,open('model.pkl','wb'))
